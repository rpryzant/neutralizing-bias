# %%
import pickle
from itertools import groupby
import random
import mwparserfromhell
import re
from nltk import sent_tokenize

# %%
keyfile_tsv_path = '/Users/rpryzant/Desktop/Wiki_NPOV/en_npov_edits_2008.tsv'
revision_pkl_path = '/Users/rpryzant/Desktop/Wiki_NPOV/en_npov_edits_2008.revision_text.pkl'

# %%
def load_comments(tsv_path):
    out = {}
    for l in open(tsv_path):
        parts = l.strip().split('\t')
        out[parts[0]] = {
            'rev_comment': parts[1],
            'rev_user': parts[2],
            'rev_user_text': parts[3],
            'rev_timestamp': parts[4],
            'rev_minor_edit': parts[5]
        }
    return out

comments = load_comments(keyfile_tsv_path)
revisions = pickle.load(open(revision_pkl_path, 'rb'))

# %%
def prep_tokenized_wikitext(token_list):
    if 0 in token_list:
        # multiple edits
        return
    
    x = ' '.join(token_list)
    # fix tags
    x = x.replace('< ', '<')
    x = x.replace('</ ', '</')
    x = x.replace(' >', '>')
    x = x.replace(' />', '/>')
    
    parse = mwparserfromhell.parse(x)
    plaintext = parse.strip_code()
    
    # fix pre-tokenization errors
    # replace links with their name
    m = re.match('\[{2}.*\|(.*)\]{2}', plaintext)
    if m:
        plaintext = re.sub('\[{2}.*\|(.*)\]{2}', m.group(1), plaintext)

    # Othwise get rid of the links (no name)
    plaintext = plaintext.replace('[[', '')
    plaintext = plaintext.replace(']]', '')
    
    # rm [urls] and urls
    plaintext = re.sub('\[.*?\]', '', plaintext)
    # TODO -- tokenized urls 
    
    return plaintext


def diff(prev_str, next_str):
    prev_set = set(prev_str.split())
    next_set = set(next_str.split())
    
    return prev_set.symmetric_difference(next_set)


def get_sents(prev_edit_str, next_edit_str):
    prev_sents = sent_tokenize(prev_edit_str)
    next_sents = sent_tokenize(next_edit_str)
    if len(prev_sents) != len(next_sents):
        return
    
    for i, (prev_sent, next_sent) in enumerate(zip(prev_sents, next_sents)):
        diff_size = len(diff(prev_sent, next_sent))
        if diff_size > 0:
            prev_ctx = prev_sents[i - 1] if i > 0 else ''
            post_ctx = prev_sents[i + 1] if i < len(prev_sents) - 1 else ''
            yield prev_sent, next_sent, prev_ctx + ' || ' + post_ctx


def examples_from_revision(rev_id):
    print(rev_id)
    metadata = comments[rev_id]

    if rev_id not in revisions:
        yield 'ERROR: id mismatch'

    revision = revisions[rev_id]
    prevs, nexts = revision
    
    prev_text = prep_tokenized_wikitext(prevs)
    next_text = prep_tokenized_wikitext(nexts)

    if prev_text is None or next_text is None:
        yield 'MULTIPLE EDITS'

    if not prev_text or not next_text:
        yield 'LACKING TEXT'
    
    for prev_sent, next_sent, context in get_sents(prev_text, next_text):
        ex = (
            rev_id,
            metadata['rev_comment'],
            prev_sent,
            next_sent,
            context
        )
        yield ex
        
def sample_revision(rev_id):
    try:
        ex = next(examples_from_revision(rev_id))
    except:
        ex = 'NO EXAMPLES'
    print('=' * 80)
    if isinstance(ex, str):
        print(ex)
    else:
        print('EDIT: %s \n COMMENT: %s \n\t%s\n\t%s\n\t%s' % ex)
    
#sample_revision('259892922')

# %%
for i in range(100):
    sample_revision(random.choice(list(comments)))
# Out:
# ================================================================================
# NO EXAMPLES
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 222535314
#  COMMENT: npov
# 	Interestingly ,  Bellone ' s goal was the only one of France ' s fourteen goals to be scored by a striker .
# 	Bellone ' s goal was the only one of France ' s fourteen goals to be scored by a striker .
# 	Bruno Bellone  doubled France ' s lead in the final minute to give them a 20 victory . ||
# ================================================================================
# NO EXAMPLES
# ================================================================================
# EDIT: 229258160
#  COMMENT: removing Britishism to more neutral wording
# 	5 February   2007  saw the album  in   high   street  stores on  CD  and  DVD .
# 	5 February   2007  saw the album  released   to  stores on  CD  and  DVD .
# 	It was released on the  Internet  in December  2006 . || The album consists of both live and studio recordings of old and new songs .
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 242586722
#  COMMENT: /* The melody */ neutral language
# 	This is  deservedly  so much prized that even where Reform Judaism has abolished the recital of the Chaldaic text , the air is often preserved , in association with some other passage .
# 	This is so much prized that even where Reform Judaism has abolished the recital of the Chaldaic text , the air is often preserved , in association with some other passage .
# 	Even more famous than the formula itself is the melody traditionally attached to its rendition . ||
# ================================================================================
# EDIT: 245300947
#  COMMENT: /* Humankind */ replacing a sexist word with a neutral one
# 	  Mankind
# 	  Humankind
# 	 ||
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 256941559
#  COMMENT: /* Helicopters */ rm non-npov word
# 	Until 31 March 2008 , they also operated for the  East Midlands Ambulance Service  but after some  shamefully  public political wranglings between WMAS and EMAS , the aircraft was withdrawn by WMAS and redeployed into Tatenhill ( Staffordshire ), despite the presence of the nearby Cosford aircraft .
# 	Until 31 March 2008 , they also operated for the  East Midlands Ambulance Service  but after some public political wranglings between WMAS and EMAS , the aircraft was withdrawn by WMAS and redeployed into Tatenhill ( Staffordshire ), despite the presence of the nearby Cosford aircraft .
# 	These services include the  West Midlands Ambulance Service  and the  Great Western Ambulance Service . ||
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 242790861
#  COMMENT: /* Impact */ neutral language
# 	Although their car was not an Aston Martin , they  proved  that such ejector seat works nearly identically to what was seen on film .
# 	Although their car was not an Aston Martin , they  concluded  that such ejector seat works nearly identically to what was seen on film .
# 	The MythBusters also recreated the ejector seat of the DB5 . ||
# ================================================================================
# NO EXAMPLES
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 223060030
#  COMMENT: resisance is pov
# 	| known_for = Symbol  of   Palestinian resistance  as captured in the famous image of him published worldwide
# 	| known_for = Symbol  for   Palestinians  as captured in the famous image of him published worldwide
# 	 ||
# ================================================================================
# EDIT: 219577520
#  COMMENT: /* Four-mallet style */ "she" sounds weird... "they" is acceptable as a third-person singular gender neutral pronoun.
# 	As the player strikes a black note with a mallet ,  she  simultaneously  presses  the heel of  her  hand or the side of  her  pinky finger onto the ringing white bar , using the same hand to strike the black note and dampen the white note .
# 	As the player strikes a black note with a mallet ,  they  simultaneously  press  the heel of  their  hand or the side of  their  pinky finger onto the ringing white bar , using the same hand to strike the black note and dampen the white note .
# 	Hand dampening ( also know as finger dampening ) can be used to dampen a white note while striking a nearby black note . || Using both hands , it ' s possible to dampen and strike two notes at once .
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 190308542
#  COMMENT: npov editing
# 	Critics of the movement often assert that  emergents  frequently indulge in logical  fallacies , especially the false antithesis or  false dilemma , and self contradiction .
# 	Critics of the movement often assert that  some proponents  frequently indulge in logical  fallacies , especially the false antithesis or  false dilemma , and self contradiction .
# 	 || Smith , 97 - 98  Some evangelical authors have responded that the  emergent church  tendency to paint Evangelicalism as culture - bound to modernism is a  straw man  argument  Carson , 59 - 60  and they respond that Evangelicalism has never embraced modernism in its entirety in spite of its acceptance of the  correspondence theory of truth  and  semantic externalism .
# ================================================================================
# NO EXAMPLES
# ================================================================================
# EDIT: 183931988
#  COMMENT: /* Economically neutral */  [
# 	The only direct effect of LVT on prices is to lower the market price of land .<ref>[ Adam Smith ,  The Wealth of Nations  Book V , Chapter 2 , Article I : Taxes upon the Rent of Houses :
# 	The only direct effect of LVT on prices is to lower the market price of land .<ref>  [  [ Adam Smith ,  The Wealth of Nations  Book V , Chapter 2 , Article I : Taxes upon the Rent of Houses :
# 	Because the supply of land is  inelastic  market land rents depend on what tenants are prepared to pay rather than on the expenses of landlords , and so LVT cannot be  passed on  to tenants . ||
# ================================================================================
# EDIT: 211994254
#  COMMENT: "highly rated" removed due to citation being from Scientology and not neutral. Would be NPOV if rewote as "Highly Rated by Scientology
# 	''' The Mace - Kingsley Ranch School  '''  was  a highly - rated   school for teens with behavioral and emotional problems in a  rural  ranch environment .
# 	''' The Mace - Kingsley Ranch School was school for teens with behavioral and emotional problems in a  rural  ranch environment .
# 	 || It was established in 1987 in  Reserve , New Mexico .
# ================================================================================
# EDIT: 193172450
#  COMMENT: /* Molecular equidistance */ npov
# 	Denton ' s conclusions have been  generally  called " erroneous " and " spurious "*, 249268 .
# 	Denton ' s conclusions have been called " erroneous " and " spurious "*, 249268 .
# 	 || doi : 10 .
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 212939317
#  COMMENT: /* Qantas first fleet and flight */ too much pov in that statement :-S
# 	The time in  the  North   Gregory   Hotel   proved   to   be   a   significant   one  ,  with   McMaster   outlined  the  links   between   aviation and defense  .
# 	In  the  hotel ,   McMaster   outlined   the   links   between   aviation   and   defense  ,  in   reference   to  the  future   of   Qantas  .
# 	Retrieved on  October 9 ,  2007 . || Gunn ( 1985 ). "
# ================================================================================
# EDIT: 196579198
#  COMMENT: multiple issues with the image - copy vio, non-neutral, privacy, etc. And I'm not an Obama supporter, just following WP policy
# 	 Tony Rezko  and   the   alleged property in   the   case
# 	 thumb | right | Tony Rezko  with   Bill   and   Hillary   Clinton
# 	 ||
# ================================================================================
# LACKING TEXT
# ================================================================================
# EDIT: 216105212
#  COMMENT: copy-edit: "turned her back on" sounded somewhat judgmental, so substituted more neutral "abandoned"
# 	Other novels followed until  1992 , when she  turned   her back on  writing to make and sell jewelry .
# 	Other novels followed until  1992 , when she  abandoned  writing to make and sell jewelry .
# 	She continued to write short stories throughout the  1960s  and in  1971 , published her first novel ,  Saltflower . || Retired now , she gardens and has begun to write  science fiction  again .
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# 	 || SecuROM aims to resist home media duplication devices , professional duplicators , and  reverse engineering  attempts .
# ================================================================================
# EDIT: 189182083
#  COMMENT: pov
# 	Although reedfish are not commonly found in aquarium stores  , they make wonderful pets  .
# 	Although reedfish are not commonly found in aquarium stores .
# 	 || They are generally priced from $ 20 to about $ 40 , ( approx .
# ================================================================================
# EDIT: 231919121
#  COMMENT: Non-neutral? You want to say NATO didn't bomb civilians? NATO killed more than 2,500 Serbian civilians and also Chinese and other. It's a fact, not a POV.
# 	  1999 :  1999 NATO bombing of the Federal Republic of Yugoslavia  between  March 24  and  June 10   1999 , during which NATO attacked Yugoslav targets , Albanian guerrillas continued battles with Yugoslav forces , amidst a massive displacement of population in Kosovo .
# 	  1999 :  1999 NATO bombing of the Federal Republic of Yugoslavia  between  March 24  and  June 10   1999 , during which NATO attacked Yugoslav targets  and civilians  , Albanian guerrillas continued battles with Yugoslav forces , amidst a massive displacement of population in Kosovo .
# 	 ||
# ================================================================================
# EDIT: 232033707
#  COMMENT: more neutral term
# 	The  Andamanese  ( Sentinel , Onge , Jarawa , Great Andamanese ) barely  survive  on some of the Andaman Islands and speak a language isolate , as do the Kusunda in central Nepal  D .
# 	The  Andamanese  ( Sentinel , Onge , Jarawa , Great Andamanese ) barely  subsist  on some of the Andaman Islands and speak a language isolate , as do the Kusunda in central Nepal  D .
# 	Minority groups not falling within either large group mostly belong to the  Austro - Asiatic  and  Tibeto - Burman  phyla . || E .
# ================================================================================
# EDIT: 251012165
#  COMMENT: cut some pov that seems to be pushing it
# 	This  anger  was  certainly  accelerated by the racism of the time  , but arguably had a basis in Imperial Japanese actions , which were ethically , by Western standards , massively depraved and few steps above utter barbarism  .
# 	This  outrage  was accelerated by the racism of the time .
# 	and Filipino POWs , in which many died ; the utter disregard that the Imperial Japanese showed towards the Western practices of treating prisoners of war humanely ; the widely - documented abuse of captured Allied female nationals as " comfort women ", or sexual slaves , by the Imperial Japanese Army ; the use of Allied POWs as slave labor on starvation rations ; and the periodic reports of Imperial Japanese atrocities upon the Chinese , such as the  Rape of Nanking , or acts such as the Imperial Japanese Army , including the  contest to kill 100 people using a sword  in China , or the actions of  Unit 731 , including the  vivisection  of Allied POWs . ||
# ================================================================================
# EDIT: 242882939
#  COMMENT: npov
# 	pdf  He is an  evolution    denialist   and argues that  evolutionary theory  is being used as fodder for a secular campaign against  Christianity , while the alleged weaknesses in evolutionary theory are not getting the same scrutiny .
# 	pdf  He is an  evolution   skeptic  and argues that  evolutionary theory  is being used as fodder for a secular campaign against  Christianity , while the alleged weaknesses in evolutionary theory are not getting the same scrutiny .
# 	com / interview . ||
# ================================================================================
# EDIT: 217642262
#  COMMENT: precision uneccessary and npov
# 	The name is derived from the physician  George Huntington  who described  it   precisely  in 1872 .
# 	The name is derived from the physician  George Huntington  who described  the   disorder  in 1872 .
# 	 || In 1993 the gene causing HD was found , making it one of the first inherited  genetic disorder  s for which an accurate test could be performed , because of this , and the disorder having aspects applicable to other neurological disorders such as  Alzheimer ' s disease , it has been extensively researched since then .
# ================================================================================
# EDIT: 204703551
#  COMMENT: /* Merger */ remove unsourced pov claim
# 	html Worcester News   Now , the merger has been accepted and pupils and staff have fitted and got on with school life .
# 	html Worcester News
# 	uk / 2006 / 12 / 12 / 440055 . ||
# ================================================================================
# EDIT: 226643689
#  COMMENT: /* Criticism and controversies */ trying to be neutral changed "UPX claims" to "UPX asserts"
# 	However , UPX  claims  the federal standard is controversial because it only measures first time students with no college credits   Diverse ; Issues in Higher Education , June 9 , 2008  and uses measurements that skew against economically disadvantaged and minority students   The Chronicle of Higher Education ( reprinted at Susan Ohanian .
# 	However , UPX  asserts  the federal standard is controversial because it only measures first time students with no college credits   Diverse ; Issues in Higher Education , June 9 , 2008  and uses measurements that skew against economically disadvantaged and minority students   The Chronicle of Higher Education ( reprinted at Susan Ohanian .
# 	 One statistic frequently cited by critics of the university is that when calculating the federal graduation rate standard currently used by the  Department of Education , UPX ' s rate is merely 16 % and that when compared to the national average of 55 % is among the nation ' s lowest . || org , July 6 , 2007 , by Paul Attewell and David E .
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# LACKING TEXT
# ================================================================================
# EDIT: 241694691
#  COMMENT: /* History of the Archdiocese */ pov edit
# 	There have been several instances in the history of the Catholic Church in Westminster when its devoted followers were persecuted by English governments : most notably during the reign of  Queen   Elizabeth I  ( 1558 - 1603 ) and during the  mercifully  shorter administration of the Republican  Lord Protector   Oliver Cromwell  ( 1653 - 1658 ).
# 	There have been several instances in the history of the Catholic Church in Westminster when its devoted followers were persecuted by English governments : most notably during the reign of  Queen   Elizabeth I  ( 1558 - 1603 ) and during the shorter administration of the Republican  Lord Protector   Oliver Cromwell  ( 1653 - 1658 ).
# 	 ||
# ================================================================================
# EDIT: 228563118
#  COMMENT: please remain neutral when writing.
# 	}}</ref>  With   unmatched   hustle  , he proved to be one of the highest - profile ministers during the so - called " Phony War ", when the only noticeable action was at sea .
# 	}}</ref>  In   this   job  , he proved to be one of the highest - profile ministers during the so - called " Phony War ", when the only noticeable action was at sea .
# 	 || Churchill advocated the pre - emptive occupation of the neutral Norwegian  iron - ore  port of  Narvik  and the iron mines in  Kiruna ,  Sweden , early in the war .
# ================================================================================
# EDIT: 185532653
#  COMMENT: rvt pov edit again
# 	It is added to some toothpastes to reduce  periodontal disease .
# 	It is added to some toothpastes to reduce  periodontal disease   , and is used in  homeopathic medicine  under the name of  strontium chlorii   .
# 	Strontium chloride is occasionally used as a flame colouring agent ( red ) in  pyrotechnics , and in small quantities in  glass  making and  metallurgy . ||
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 212813871
#  COMMENT: /* Events */ npov
# 	 1967  - The city of  Jerusalem  is  returned   to   the   nation   of    Israel
# 	 1967  - The city of  Jerusalem  is  captured   by    Israel    during   the    six - day war
# 	 ||
# ================================================================================
# EDIT: 201776867
#  COMMENT: Edited to reflect a more neutral viewpoint regarding the Tsay Keh Dene.
# 	The  surviving  Tsay Keh Dene  finally  received  a  compensation  package  from the Province in the autumn of 2006  , almost forty years late  .
# 	The Tsay Keh Dene received  additional  compensation from the Province in the autumn of 2006 .
# 	A great many of them wound up living on the streets of Prince George and Vancouver , and , of those , many did not live long . ||
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 243472835
#  COMMENT: Opening clause tightened up and made more neutral.
# 	In the case of  Catholics , however , it was disastrous both socially and politically .
# 	For  Catholics , however , it was disastrous both socially and politically .
# 	The deposition of the  Roman Catholic  James II ended any chance of  Catholicism becoming re - established in England , and also led to limited toleration for  nonconformist   Protestants  it would be some time before they had full  political rights . || Catholics were denied the right to vote and sit in the Westminster Parliament for over 100 years after this .
# ================================================================================
# LACKING TEXT
# ================================================================================
# NO EXAMPLES
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 205149257
#  COMMENT: /* Proposed beating of Stuart Collier */ fix pov header
# 	  Proposed beating of  Stuart Collier
# 	 Stuart Collier
# 	 ||
# ================================================================================
# NO EXAMPLES
# ================================================================================
# EDIT: 222301967
#  COMMENT: /* Joseph Estabrook Elementary School */ how about that? stating was was "indoctrination" is obviously non-neutral
# 	The school garnered nationwide attention in 2005 from the  David Parker controversy , concerning a conservative couple ( David and Tonia Parker ) who  did   not wish  their young child  to   be  indoctrinated by public school teachers to embrace and affirm homosexual conduct and " gay marriage ".
# 	The school garnered nationwide attention in 2005 from the  David Parker controversy , concerning a conservative couple ( David and Tonia Parker ) who  claimed   that  their young child  was   being  indoctrinated by public school teachers to embrace and affirm homosexual conduct and " gay marriage ".
# 	 || The bulk of the legality of the controversy revolved around whether parents have a right to receive parental notification and opt their elementary school children out of such  indoctrination sessions  .
# ================================================================================
# EDIT: 221513327
#  COMMENT: pov heading
# 	  War on  Drugs
# 	 Drugs
# 	 ||
# ================================================================================
# EDIT: 234063585
#  COMMENT: /* Organization */ Changed "says" (which can imply falsehood) to the neutral "according to" per [[WP:NPOV]].
# 	 The  JIDF  says   it  " formed as a grassroots effort in 2000 , mainly to mount mass e - mail campaigns , in response to the  second intifada .
# 	 According to the  JIDF  ,   the   organization  " formed as a grassroots effort in 2000 , mainly to mount mass e - mail campaigns , in response to the  second intifada .
# 	 || It then began operating on various Web sites , including Facebook , to spread news about Israel and Jewish issues .
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# NO EXAMPLES
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# MULTIPLE EDITS
# ================================================================================
# EDIT: 205818103
#  COMMENT: /* Economic evolution */ removing pov see talk page
# 	In the aftermath of the Korean War and throughout the 1960s the country ' s state - controlled  economy   slowed down  at a significant rate .
# 	In the aftermath of the Korean War and throughout the 1960s the country ' s state - controlled  economy   grew  at a significant rate .
# 	 || It  may also have once been  considered the 2nd - most  industrialized  nation in Asia , after  Japan .

# %%
sample_revision('226054404')
# Out:
# ================================================================================
# EDIT: 226054404  COMMENT: On second thought: "Northern Epirus" is not a neutral geographical term, but I guess as a marker of the minority it does make sense here
# 	 The population  is indigenous ethnic  Greek   http :// mondediplo .
# 	 It  is  home to an  indigenous ethnic  Greek   population , part of the  Northern Epirote  Greek minority   http :// mondediplo .
# 	 It is located less than 1 km north - west of the  Greek  border . || com / maps / albanianmdv1999 The Albanians , a scattered people by Philippe Rekacewicz , Le Monde diplomatique , January 1999  http :// www .

# %%
i = 0
for rev_id in list(comments)[1:]:
    for ex in examples_from_revision(rev_id):
        if not isinstance(ex, str):
            i += 1
print(i)
# Out:
# 237443965
# 237443965
# 243920179
# 243920179
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-261-76d39d87e465> in <module>
#       2 for rev_id in list(comments)[1:]:
#       3     print(rev_id)
# ----> 4     for ex in examples_from_revision(rev_id):
#       5         if not isinstance(ex, str):
#       6             i += 1
#
# <ipython-input-257-9d00522906ec> in examples_from_revision(rev_id)
#      71         yield 'LACKING TEXT'
#      72
# ---> 73     for prev_sent, next_sent, context in get_sents(prev_text, next_text):
#      74         ex = (
#      75             rev_id,
#
# <ipython-input-257-9d00522906ec> in get_sents(prev_edit_str, next_edit_str)
#      40 def get_sents(prev_edit_str, next_edit_str):
#      41     prev_sents = sent_tokenize(prev_edit_str)
# ---> 42     next_sents = sent_tokenize(next_edit_str)
#      43     if len(prev_sents) != len(next_sents):
#      44         return
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1239         Given a text, returns a list of the sentences in that text.
#    1240         """
# -> 1241         return list(self.sentences_from_text(text, realign_boundaries))
#    1242
#    1243     def debug_decisions(self, text):
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1289         follows the period.
#    1290         """
# -> 1291         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1292
#    1293     def _slices_from_text(self, text):
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1289         follows the period.
#    1290         """
# -> 1291         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1292
#    1293     def _slices_from_text(self, text):
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1279         if realign_boundaries:
#    1280             slices = self._realign_boundaries(text, slices)
# -> 1281         for sl in slices:
#    1282             yield (sl.start, sl.stop)
#    1283
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1320         """
#    1321         realign = 0
# -> 1322         for sl1, sl2 in _pair_iter(slices):
#    1323             sl1 = slice(sl1.start + realign, sl1.stop)
#    1324             if not sl2:
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     311     """
#     312     it = iter(it)
# --> 313     prev = next(it)
#     314     for el in it:
#     315         yield (prev, el)
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1293     def _slices_from_text(self, text):
#    1294         last_break = 0
# -> 1295         for match in self._lang_vars.period_context_re().finditer(text):
#    1296             context = match.group() + match.group('after_tok')
#    1297             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
