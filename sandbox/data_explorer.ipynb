# %% [markdown]
# ### little notebook for poking around at the data, getting a handle for cleaning things up, etc

# %%
import pickle
from itertools import groupby
import random
import mwparserfromhell
import re
from nltk import sent_tokenize

# %%
keyfile_tsv_path = '/Users/rpryzant/Desktop/Wiki_NPOV/en_npov_edits_2008.tsv'
revision_pkl_path = '/Users/rpryzant/Desktop/Wiki_NPOV/en_npov_edits_2008.revision_text.pkl'

# %%
def load_comments(tsv_path):
    out = {}
    for l in open(tsv_path):
        parts = l.strip().split('\t')
        out[parts[0]] = {
            'rev_comment': parts[1],
            'rev_user': parts[2],
            'rev_user_text': parts[3],
            'rev_timestamp': parts[4],
            'rev_minor_edit': parts[5]
        }
    return out

comments = load_comments(keyfile_tsv_path)
revisions = pickle.load(open(revision_pkl_path, 'rb'))

# %%
def prep_tokenized_wikitext(token_list):
#    token_list = [tok if tok != 0 else '___' for tok in token_list ]

    if 0 in token_list:
        # multiple edits
        return
    
    x = ' '.join(token_list)
    # fix tags
    x = x.replace('< ', '<')
    x = x.replace('</ ', '</')
    x = x.replace(' >', '>')
    x = x.replace(' />', '/>')
    
    parse = mwparserfromhell.parse(x)
    plaintext = parse.strip_code()
    
    # fix pre-tokenization errors
    # replace links with their name
    m = re.match('\[{2}.*\|(.*)\]{2}', plaintext)
    if m:
        plaintext = re.sub('\[{2}.*\|(.*)\]{2}', m.group(1), plaintext)

    # Othwise get rid of the links (no name)
    plaintext = plaintext.replace('[[', '')
    plaintext = plaintext.replace(']]', '')
    
    # rm [urls] and urls
    plaintext = re.sub('\[.*?\]', '', plaintext)
    # TODO -- tokenized urls 
#    print(plaintext)
    return plaintext


def diff(prev_str, next_str):
    prev_set = set(prev_str.split())
    next_set = set(next_str.split())
    
    return prev_set.symmetric_difference(next_set)


def get_sents(prev_edit_str, next_edit_str):
    prev_sents = sent_tokenize(prev_edit_str)
    next_sents = sent_tokenize(next_edit_str)
    if len(prev_sents) != len(next_sents):
        return
    
    for i, (prev_sent, next_sent) in enumerate(zip(prev_sents, next_sents)):
        diff_size = len(diff(prev_sent, next_sent))
        if diff_size > 0:
            prev_ctx = prev_sents[i - 1] if i > 0 else ''
            post_ctx = prev_sents[i + 1] if i < len(prev_sents) - 1 else ''
            yield prev_sent, next_sent, prev_ctx + ' || ' + post_ctx


def examples_from_revision(rev_id):
    print(rev_id)
    metadata = comments[rev_id]

    if rev_id not in revisions:
        yield 'ERROR: id mismatch'

    revision = revisions[rev_id]
    prevs, nexts = revision
    
    prev_text = prep_tokenized_wikitext(prevs)
    next_text = prep_tokenized_wikitext(nexts)
    
    if prev_text is None or next_text is None:
        yield 'MULTIPLE EDITS'

    if len(prev_text) == 0 or len(next_text) == 0:
        yield 'LACKING TEXT'
    
    for prev_sent, next_sent, context in get_sents(prev_text, next_text):
        ex = (
            rev_id,
            metadata['rev_comment'],
            prev_sent,
            next_sent,
            context
        )
        yield ex
        
def sample_revision(rev_id):
    try:
        ex = next(examples_from_revision(rev_id))
    except:
        ex = 'NO EXAMPLES'
    print('=' * 80)
    if isinstance(ex, str):
        print(ex)
    else:
        print('EDIT: %s \n COMMENT: %s \n\t%s\n\t%s\n\t%s' % ex)
    
#sample_revision('259892922')

# %%
for i in range(100):
    sample_revision(random.choice(list(comments)))
# Out:
# 230733470
# ================================================================================
# MULTIPLE EDITS
# 260203068
# ================================================================================
# MULTIPLE EDITS
# 221579447
# ================================================================================
# EDIT: 221579447
#  COMMENT: pov
# 	These Pokmon can be  illegitimately  obtained by using a  GameShark  or similar cheating device like Action Replay .
# 	These Pokmon can be obtained by using a  GameShark  or similar cheating device like Action Replay .
# 	They are obtained by using the Mystery Gift function ; in some cases , exploiting a glitch in the game itself ; or directly from Nintendo at promotional events . || Players are not required to own these Pokmon , among others , in order to have a complete  Pokdex .
# 225636756
# ================================================================================
# MULTIPLE EDITS
# 227336794
# ================================================================================
# LACKING TEXT
# 226993854
# ================================================================================
# EDIT: 226993854
#  COMMENT: /* Modern excavation */ I think "non-independent" here is redundant and pov in itself. just relaying the teams findings will let the user make up his/her own mind.
# 	Between 1939 and 1949 the  non - independent  Vatican - led archaeological team had uncovered a complex of undoubtedly  pagan  mausoleums under the foundations of  St .
# 	Between 1939 and 1949 the Vatican - led archaeological team had uncovered a complex of undoubtedly  pagan  mausoleums under the foundations of  St .
# 	 || Peter ' s Basilica , dating to the 2nd and 3rd centuries .
# 249767240
# ================================================================================
# EDIT: 249767240
#  COMMENT: rm pov
# 	Living in a log cabin he constructed by hand , Proenneke made valuable recordings of both  meteorological  and natural data  while enjoying his retirement  .
# 	Living in a log cabin he constructed by hand , Proenneke made valuable recordings of both  meteorological  and natural data .
# 	 Richard Louis " Dick " Proenneke  ( May 4   1916 & ndash ; April 28 ,  2003 ) was a  naturalist  and  survivalist  who lived alone in the high mountains of  Alaska  at a place called  Twin Lakes . ||
# 187490281
# ================================================================================
# EDIT: 187490281
#  COMMENT: /* Iran 1953 */ less pov
# 	| year = 2000 }}</ref>  The prize was Iran ' s oil fields ; in  1951 the  Iranian parliament  voted to nationalize the oil fields of the country .
# 	| year = 2000 }}</ref>  In  1951 the  Iranian parliament  voted to nationalize the oil fields of the country .
# 	 || Anti - Communism had also risen to a fever pitch in Washington , and officials were worried that Iran might fall under the sway of the Soviet Union , a historical presence there . "
# 234026118
# ================================================================================
# MULTIPLE EDITS
# 199770772
# ================================================================================
# MULTIPLE EDITS
# 185645287
# ================================================================================
# MULTIPLE EDITS
# 227854988
# ================================================================================
# MULTIPLE EDITS
# 235030925
# ================================================================================
# EDIT: 235030925
#  COMMENT: /* Academics */ npov'd
# 	UTS  is well known for its  enriched courses and specialized curriculum , which are designed to challenge and educate at a higher level than at most public and many independent schools .
# 	UTS  has  enriched courses and  a  specialized curriculum , which are designed to challenge and educate at a higher level than at most public and many independent schools .
# 	 || Because potential UTS candidates are required to pass a rigorous entrance examination to attend the school , its curriculum is accelerated on the assumption that its students assimilate information faster .
# 192190541
# ================================================================================
# EDIT: 192190541
#  COMMENT: Removed pov
# 	It is no longer recognized as a province of  Serbia  ( under the name of  Autonomous Province of Kosovo and Metohija ) (,  Autonomna pokrajina Kosovo i Metohija , also ,  Kosmet ; ) by  many of the world ' s foremost  nations  ,  such as the  United States ,  United Kingdom , and many members of the  European Union .
# 	It is no longer recognized as a province of  Serbia  ( under the name of  Autonomous Province of Kosovo and Metohija ) (,  Autonomna pokrajina Kosovo i Metohija , also ,  Kosmet ; ) by nations such as the  United States ,  United Kingdom , and many members of the  European Union .
# 	 || Since 1999 it has been under the  administration  of the  United Nations  ( see :  Resolution 1244 ), with security provided by the  NATO - led  Kosovo Force .
# 254134351
# ================================================================================
# LACKING TEXT
# 242921342
# ================================================================================
# EDIT: 242921342
#  COMMENT: /* Special legislative session */ -"supporters of Superferry were booed and yelled at" sounds kind of pov, sorry...
# 	On Kauai , the meeting was calm , however on Maui the meeting was  heated   and   supporters of Superferry were booed and yelled at  .
# 	On Kauai , the meeting was calm , however on Maui the meeting was  more   emotionally   charged  .
# 	In preparation , members of the Legislature made trips to  Kauai ,  Maui , and  The Big Island  to get reactions . ||
# 184813311
# ================================================================================
# MULTIPLE EDITS
# 202978174
# ================================================================================
# MULTIPLE EDITS
# 217270804
# ================================================================================
# MULTIPLE EDITS
# 212062143
# ================================================================================
# MULTIPLE EDITS
# 185002767
# ================================================================================
# MULTIPLE EDITS
# 185825193
# ================================================================================
# EDIT: 185825193
#  COMMENT: /* 1946-60: Original era */ pov -  not won by both sides
# 	Seven years later , after the war had  been won  , a second effort to bring ice hockey to the city was begun .
# 	Seven years later , after the war had  ended  , a second effort to bring ice hockey to the city was begun .
# 	A team was assembled and brought to the  United Kingdom  from  Canada  to compete in the 193940  English National League  season but were promptly sent home having not played a single game due to the outbreak of  World War II . || With a team of Canadians largely from  Winnipeg ,  Manitoba , the Nottingham Panthers played their first competitive game on  November 22 ,  1946  with a 32 home victory over the  Wembley Monarchs .
# 183468425
# ================================================================================
# NO EXAMPLES
# 253611464
# ================================================================================
# LACKING TEXT
# 225477106
# ================================================================================
# MULTIPLE EDITS
# 184472286
# ================================================================================
# NO EXAMPLES
# 187810370
# ================================================================================
# LACKING TEXT
# 191415012
# ================================================================================
# NO EXAMPLES
# 218213442
# ================================================================================
# EDIT: 218213442
#  COMMENT: pov pushing
# 	Knight ' s middle son ,  David Knight , who is gay ,  married   his   longtime   partner  in San Francisco ; the marriage was later nullified by the  California Supreme Court  in March 2004 .
# 	Knight ' s middle son ,  David Knight , who is gay ,  attempted   to   marry   the guy he was having sex with for that week  in San Francisco ; the marriage was later nullified by the  California Supreme Court  in March 2004 .
# 	During his term in the Senate , Knight gained statewide attention as the author of  Proposition 22 , aka the " Knight Initiative ," whose entire text stated , " Only marriage between a man and a woman is valid or recognized in California ." || http :// www .
# 248230132
# ================================================================================
# EDIT: 248230132
#  COMMENT: more neutral wording
# 	| pages = 103 - 104 }}</ref>  The   ANC   was very hostile to  Biko  and to Black Consciousness  through the 70s to the mid 90s   but  has  now  included Biko in the pantheon of struggle heroes , going  so  far  to   use  his image for campaign posters in South Africa ' s first non - racial elections  ,  in 1994 .
# 	| pages = 103 - 104 }}</ref>  Despite friction between the   ANC   and  Biko through the 70s to the mid 90s   the ANC  has included Biko in the pantheon of struggle heroes , going  as  far  as   using  his image for campaign posters in South Africa ' s first non - racial elections in 1994 .
# 	 || See , for instance , Rian Malan ' s book My Traitor ' s Heart
# 217471237
# ================================================================================
# MULTIPLE EDITS
# 238541434
# ================================================================================
# MULTIPLE EDITS
# 250533716
# ================================================================================
# MULTIPLE EDITS
# 209363072
# ================================================================================
# MULTIPLE EDITS
# 230284779
# ================================================================================
# MULTIPLE EDITS
# 222369887
# ================================================================================
# LACKING TEXT
# 182853384
# ================================================================================
# MULTIPLE EDITS
# 240077998
# ================================================================================
# EDIT: 240077998
#  COMMENT: pov
# 	 Oliver Patric Neuville  ( born  May 1 ,  1973  in  Locarno ,  Switzerland ) is a  German   footballer , currently playing as a  pacy   forward  with  Borussia Mnchengladbach .
# 	 Oliver Patric Neuville  ( born  May 1 ,  1973  in  Locarno ,  Switzerland ) is a  German   footballer , currently playing as a  forward  with  Borussia Mnchengladbach .
# 	 || He was born of a  German  father and an  Italian  mother .
# 190925260
# ================================================================================
# EDIT: 190925260
#  COMMENT: /* Variety of services */ pov - - > fact tag
# 	Urmila  continues to develop and teach  local , national , and international seminars for trainers , educators , and managers which she has done for 22 years .
# 	Urmila  gives  local , national , and international seminars for trainers , educators , and managers which she has done for 22 years .
# 	For 10 years she was a member of ISKCONs international board of education , and for 7 years was vice - chairman of the North American board . || {{  POV - statement  }} She has developed and taught numerous courses for elementary , high school , college , and adult learners in a wide variety of subjects using interactive and experiential learning in addition to lecture .
# 219745231
# ================================================================================
# MULTIPLE EDITS
# 218073205
# ================================================================================
# MULTIPLE EDITS
# 188582619
# ================================================================================
# MULTIPLE EDITS
# 259312881
# ================================================================================
# MULTIPLE EDITS
# 207681749
# ================================================================================
# NO EXAMPLES
# 241648672
# ================================================================================
# LACKING TEXT
# 256935436
# ================================================================================
# EDIT: 256935436
#  COMMENT: pov
# 	| accessdate = 2008 - 11 - 17 }}</ref>, is a  controversial  United States  federal law  ( Act of Congress ) that was originally proposed by  President George W .
# 	| accessdate = 2008 - 11 - 17 }}</ref>, is a United States  federal law  ( Act of Congress ) that was originally proposed by  President George W .
# 	 || Bush  on January 23 , 2001 , immediately after taking office .
# 195767774
# ================================================================================
# EDIT: 195767774
#  COMMENT: /* Less common ASBOs */ lessened pov
# 	 A 17 - year - old forbidden to use his front door .
# 	 A 17 - year - old forbidden to use his front door  , as his anti - social behaviour when using the street outside his house and entering the front door was causing his neighbours distress  .
# 	 || "", icWales .
# 211605805
# ================================================================================
# NO EXAMPLES
# 253593749
# ================================================================================
# LACKING TEXT
# 252198765
# ================================================================================
# MULTIPLE EDITS
# 246845916
# ================================================================================
# EDIT: 246845916
#  COMMENT: rm pov
# 	Jayasuriya is part of the  Mumbai Indians  team of the  Indian Premier League  and opens the batting with  fellow legend   Sachin Tendulkar .
# 	Jayasuriya is part of the  Mumbai Indians  team of the  Indian Premier League  and opens the batting with  Sachin Tendulkar .
# 	 ||
# 234374651
# ================================================================================
# MULTIPLE EDITS
# 181619337
# ================================================================================
# MULTIPLE EDITS
# 260499533
# ================================================================================
# LACKING TEXT
# 252978665
# ================================================================================
# EDIT: 252978665
#  COMMENT: rmv pov phrasing in title for section
# 	 Tax evasion charges  and exile
# 	 Tax evasion charges
# 	 ||
# 247830108
# ================================================================================
# EDIT: 247830108
#  COMMENT: more neutral
# 	}}</ref>  in  Zulu ) is a free  operating system  based on  Debian  | Debian GNU / Linux  .
# 	}}</ref>  in  Zulu ) is a free  operating system  based on  Debian .
# 	 || Its name comes from the  Zulu  word " ubuntu ", loosely translated as " humanity ", describing the  ubuntu philosophy : " A person is a person only through other people ".
# 214946728
# ================================================================================
# EDIT: 214946728
#  COMMENT: /* Return to Form */ rm pov. also most players only play a few times at any given overseas ground so big averages happen a lot
# 	It was also his third consecutive century at SCG , giving him  a whopping  average well above 90 at the ground .
# 	It was also his third consecutive century at SCG , giving him  an  average well above 90 at the ground .
# 	It was his 12th hundred in test matches , and his 5th against Australia . ||
# 230999668
# ================================================================================
# MULTIPLE EDITS
# 206449881
# ================================================================================
# NO EXAMPLES
# 195510443
# ================================================================================
# EDIT: 195510443
#  COMMENT: /* Jiang Qing on trial (1980-1981) */ took out (possible) pov
# 	  Jiang Qing on trial (  1980 - 1981  )
# 	 1980 - 1981
# 	 ||
# 242119375
# ================================================================================
# MULTIPLE EDITS
# 258689793
# ================================================================================
# EDIT: 258689793
#  COMMENT: /* Economy */ pov & inconsistency
# 	Whitefield ' s proximity to the M60 orbital motorway and city of Manchester has ensured that there are many  flourishing   industries   as   well   as retail parks  located locally .
# 	Whitefield ' s proximity to the M60 orbital motorway and city of Manchester has ensured that there are many  small   businesses   and   trading   estates  located locally .
# 	 || Whitefield has experienced several new commercial developments since the turn of the century , for example with the replacement of Elms shopping precinct by a new gym and several new outlets and with a new  Morrisons  supermarket built on land previously occupied by a public house , the bus station and a former retail premises which had seen several uses .
# 207337009
# ================================================================================
# EDIT: 207337009
#  COMMENT: /* Selective quotation from Charles Darwin */ removing pov
# 	The same  misleading  selective quotation from this passage was used by anti - evolutionist  William Jennings Bryan  in the 1925  Scopes Trial ,  but  the full passage  makes   it   clear   that  Darwin  was   not   advocating   eugenics .
# 	The same selective quotation from this passage was used by anti - evolutionist  William Jennings Bryan  in the 1925  Scopes Trial ,  though  the full passage  is   unclear   regarding   what  Darwin  ' s   position would   be   on   eugenics .
# 	 || The eugenics movement relied on simplistic and faulty assumptions about heredity , and by the 1920s evolutionary biologists were criticizing eugenics .
# 235370549
# ================================================================================
# MULTIPLE EDITS
# 198196640
# ================================================================================
# MULTIPLE EDITS
# 205545137
# ================================================================================
# MULTIPLE EDITS
# 217907393
# ================================================================================
# LACKING TEXT
# 236871933
# ================================================================================
# NO EXAMPLES
# 205377166
# ================================================================================
# MULTIPLE EDITS
# 196804551
# ================================================================================
# NO EXAMPLES
# 253714599
# ================================================================================
# MULTIPLE EDITS
# 218942345
# ================================================================================
# EDIT: 218942345
#  COMMENT: npov - murder changed to death
# 	In August 2007 , Diabolic Video director Chico Wang was under investigation by police in  King City , California   for  the  murder  of his wife , adult - film actress  Haley Paige .
# 	In August 2007 , Diabolic Video director Chico Wang was under investigation by police in  King City , California   in  the  death  of his wife , adult - film actress  Haley Paige .
# 	 || In late September 2007 , he was found dead in a hotel room , apparently on the run .
# 205338224
# ================================================================================
# EDIT: 205338224
#  COMMENT: maori is a little more descriptive and npov
# 	|  native  name =  Te Wai Pounamu
# 	|  Maori  name =  Te Wai Pounamu
# 	 ||
# 254750968
# ================================================================================
# EDIT: 254750968
#  COMMENT: /* Criticism */  Removed bias from criticism statement and replaced with neutral statement.
# 	With the shift towards consumer uses for SUVs and pickups , the original rationale for exempting trucks is  no   longer   obviously   valid  .
# 	With the shift towards consumer uses for SUVs and pickups , the original rationale for exempting trucks is  considered   invalid   by   critics of the current tax law  .
# 	When the tax was first introduced , light trucks were viewed as primarily work related vehicles . ||
# 195538064
# ================================================================================
# MULTIPLE EDITS
# 231815360
# ================================================================================
# MULTIPLE EDITS
# 240555892
# ================================================================================
# MULTIPLE EDITS
# 199849867
# ================================================================================
# MULTIPLE EDITS
# 249157915
# ================================================================================
# MULTIPLE EDITS
# 204165334
# ================================================================================
# EDIT: 204165334
#  COMMENT: pov
# 	 Ballbreaker  is an album by the  iconic   hard rock  band  AC / DC , released in 1995 .
# 	 Ballbreaker  is an album by the   Australia  n   hard rock  band  AC / DC , released in 1995 .
# 	 || It was the band ' s first studio album in five years , since  The Razors Edge  ( 1990 ).
# 217195560
# ================================================================================
# EDIT: 217195560
#  COMMENT: language neutral
# 	 turning or shaking the  torch  itself
# 	 turning or shaking the  device  itself
# 	 ||
# 195296141
# ================================================================================
# EDIT: 195296141
#  COMMENT: pov
# 	 Rock Steady With Flo & Eddie  was  Flo & Eddie ' s last album as a duo ,  in which they took a turn for the unusual : the album was  a strait - laced collection of  reggae  songs recorded at  Bob Marley ' s  Tuff Gong Studios  in  Kingston ,  Jamaica , including a remake of the  1967   Turtles  hit " Happy Together ."
# 	 Rock Steady With Flo & Eddie  was  Flo & Eddie ' s last album as a duo , a strait - laced collection of  reggae  songs recorded at  Bob Marley ' s  Tuff Gong Studios  in  Kingston ,  Jamaica , including a remake of the  1967   Turtles  hit " Happy Together ."
# 	 || The album was released in  1981 .
# 222239029
# ================================================================================
# NO EXAMPLES
# 242026099
# ================================================================================
# MULTIPLE EDITS
# 197372513
# ================================================================================
# LACKING TEXT
# 233242361
# ================================================================================
# NO EXAMPLES
# 245644695
# ================================================================================
# MULTIPLE EDITS
# 192936445
# ================================================================================
# EDIT: 192936445
#  COMMENT: /* Labor Party and unions */ This may be more neutral.
# 	The forestry industry has been  targeted   by   radical   environmentalists   who   have   chained   themselves   to machinery and who  have  been   active   supporters of  the Greens .
# 	The forestry industry has been  a   particular   target   of   environmental   campaigns   and   Forestry   unions  have  actively   campaigned   against  the Greens .
# 	Many supporters of the Labor Party and trade unions see the Greens ' policies as destructive of employment in industries like mining and forestry . || Left - wing trade unionists and some members of Labor ' s  Socialist Left  faction often identify more readily with the Greens , feeling sold out by Labor and sympathizing with the Greens ' social policies .
# 233333756
# ================================================================================
# MULTIPLE EDITS
# 243991959
# ================================================================================
# EDIT: 243991959
#  COMMENT: /* History */ rm pov
# 	0 ) was programmed in  Visual Basic  and quickly became popular among  more knowledgeable   P2P  users despite blocking only the common TCP protocol and being known for high RAM and CPU usage when connected to P2P networks .
# 	0 ) was programmed in  Visual Basic  and quickly became popular among  P2P  users despite blocking only the common TCP protocol and being known for high RAM and CPU usage when connected to P2P networks .
# 	The original PeerGuardian ( 1 . || By December 2003 , it had been downloaded 1 million times .
# 201420009
# ================================================================================
# MULTIPLE EDITS
# 188962268
# ================================================================================
# NO EXAMPLES
# 188962268
# ================================================================================
# NO EXAMPLES
# 255294173
# ================================================================================
# MULTIPLE EDITS
# 253506404
# ================================================================================
# MULTIPLE EDITS
# 182297459
# ================================================================================
# MULTIPLE EDITS
# 207014554
# ================================================================================
# MULTIPLE EDITS
# 182378903
# ================================================================================
# MULTIPLE EDITS
# 197789422
# ================================================================================
# EDIT: 197789422
#  COMMENT: "most astute"? npov please. none of these unsourced, subjective value appraisals.
# 	 Nir Rosen  ( born  1977  in  New York City ) is a  journalist  and  one   of the most astute observers  of  Iraq ' s  descent into  insurgency  and  civil war .
# 	 Nir Rosen  ( born  1977  in  New York City ) is a  journalist  and  a   chronicler  of  Iraq ' s  descent into  insurgency  and  civil war .
# 	 || Rosen writes on current and international affairs .
# 218610470
# ================================================================================
# MULTIPLE EDITS

# %%
sample_revision('226054404')
# Out:
# ================================================================================
# EDIT: 226054404  COMMENT: On second thought: "Northern Epirus" is not a neutral geographical term, but I guess as a marker of the minority it does make sense here
# 	 The population  is indigenous ethnic  Greek   http :// mondediplo .
# 	 It  is  home to an  indigenous ethnic  Greek   population , part of the  Northern Epirote  Greek minority   http :// mondediplo .
# 	 It is located less than 1 km north - west of the  Greek  border . || com / maps / albanianmdv1999 The Albanians , a scattered people by Philippe Rekacewicz , Le Monde diplomatique , January 1999  http :// www .

# %%
i = 0
for rev_id in list(comments)[1:]:
    for ex in examples_from_revision(rev_id):
        if not isinstance(ex, str):
            i += 1
print(i)
# Out:
# 237443965
# 237443965
# 243920179
# 243920179
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-261-76d39d87e465> in <module>
#       2 for rev_id in list(comments)[1:]:
#       3     print(rev_id)
# ----> 4     for ex in examples_from_revision(rev_id):
#       5         if not isinstance(ex, str):
#       6             i += 1
#
# <ipython-input-257-9d00522906ec> in examples_from_revision(rev_id)
#      71         yield 'LACKING TEXT'
#      72
# ---> 73     for prev_sent, next_sent, context in get_sents(prev_text, next_text):
#      74         ex = (
#      75             rev_id,
#
# <ipython-input-257-9d00522906ec> in get_sents(prev_edit_str, next_edit_str)
#      40 def get_sents(prev_edit_str, next_edit_str):
#      41     prev_sents = sent_tokenize(prev_edit_str)
# ---> 42     next_sents = sent_tokenize(next_edit_str)
#      43     if len(prev_sents) != len(next_sents):
#      44         return
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1239         Given a text, returns a list of the sentences in that text.
#    1240         """
# -> 1241         return list(self.sentences_from_text(text, realign_boundaries))
#    1242
#    1243     def debug_decisions(self, text):
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1289         follows the period.
#    1290         """
# -> 1291         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1292
#    1293     def _slices_from_text(self, text):
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1289         follows the period.
#    1290         """
# -> 1291         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1292
#    1293     def _slices_from_text(self, text):
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1279         if realign_boundaries:
#    1280             slices = self._realign_boundaries(text, slices)
# -> 1281         for sl in slices:
#    1282             yield (sl.start, sl.stop)
#    1283
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1320         """
#    1321         realign = 0
# -> 1322         for sl1, sl2 in _pair_iter(slices):
#    1323             sl1 = slice(sl1.start + realign, sl1.stop)
#    1324             if not sl2:
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     311     """
#     312     it = iter(it)
# --> 313     prev = next(it)
#     314     for el in it:
#     315         yield (prev, el)
#
# ~/persuasion/venv/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1293     def _slices_from_text(self, text):
#    1294         last_break = 0
# -> 1295         for match in self._lang_vars.period_context_re().finditer(text):
#    1296             context = match.group() + match.group('after_tok')
#    1297             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
