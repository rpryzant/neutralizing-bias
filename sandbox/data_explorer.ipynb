# %%
import pickle
from itertools import groupby
import random
import mwparserfromhell
import re
from nltk import sent_tokenize

# %%
keyfile_tsv_path = '/Users/rpryzant/Desktop/Wiki_NPOV/en_npov_edits_2010.tsv'
revision_pkl_path = '/Users/rpryzant/Desktop/Wiki_NPOV/en_npov_edits_2010.revision_text.pkl'

# %%
def load_comments(tsv_path):
    out = {}
    for l in open(tsv_path):
        parts = l.strip().split('\t')
        out[parts[0]] = {
            'rev_comment': parts[1],
            'rev_user': parts[2],
            'rev_user_text': parts[3],
            'rev_timestamp': parts[4],
            'rev_minor_edit': parts[5]
        }
    return out

comments = load_comments(keyfile_tsv_path)
revisions = pickle.load(open(revision_pkl_path, 'rb'))

# %%
def prep_tokenized_wikitext(token_list):
    if 0 in token_list:
        # multiple edits
        return
    
    x = ' '.join(token_list)
    # fix tags
    x = x.replace('< ', '<')
    x = x.replace('</ ', '</')
    x = x.replace(' >', '>')
    x = x.replace(' />', '/>')
    
    parse = mwparserfromhell.parse(x)
    plaintext = parse.strip_code()
    
    # fix pre-tokenization errors
    # replace links with their name
    m = re.match('\[{2}.*\|(.*)\]{2}', plaintext)
    if m:
        plaintext = re.sub('\[{2}.*\|(.*)\]{2}', m.group(1), plaintext)

    # Othwise get rid of the links (no name)
    plaintext = plaintext.replace('[[', '')
    plaintext = plaintext.replace(']]', '')
    
    # rm urls urls
    plaintext = re.sub('\[.*?\]', '', plaintext)

    return plaintext


def diff(prev_str, next_str):
    prev_set = set(prev_str.split())
    next_set = set(next_str.split())
    
    return prev_set.symmetric_difference(next_set)


def get_sents(prev_edit_str, next_edit_str):
    prev_sents = sent_tokenize(prev_edit_str)
    next_sents = sent_tokenize(next_edit_str)
    if len(prev_sents) != len(next_sents):
        return
    
    for prev_sent, next_sent in zip(prev_sents, next_sents):
        diff_size = len(diff(prev_sent, next_sent))
        if diff_size > 0:
            yield prev_sent, next_sent


def sample_revision(rev_id):
    metadata = comments[rev_id]

    if rev_id not in revisions:
        print('ERROR: id mismatch')
        return
    
    revision = revisions[rev_id]
    prevs, nexts = revision
    
    prev_text = prep_tokenized_wikitext(prevs)
    next_text = prep_tokenized_wikitext(nexts)

    if prev_text is None or next_text is None:
        print('MULTIPLE EDITS')
        return

    if not prev_text or not next_text:
        print('LACKING TEXT')
        return
    
    print('=' * 80)
    print('EDIT: %s  COMMENT: %s' % (rev_id, metadata['rev_comment']))
    for prev_sent, next_sent in get_sents(prev_text, next_text):
        print('\t', prev_sent)
        print('\t', next_sent)
        print()

    
#sample_revision('259892922')

# %%
for i in range(100):
    sample_revision(random.choice(list(comments)))
# Out:
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 371426825  COMMENT: rv. pov wording
# 	 These highly - publicized actions resulted in statewide acclaim  among liberal democrats  , and led to his election as governor in the next statewide election .
# 	 These highly - publicized actions resulted in statewide acclaim , and led to his election as governor in the next statewide election .
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# LACKING TEXT
# ================================================================================
# EDIT: 344721889  COMMENT: /* Unnamed characters played by a notable actor/actress */ redundant - "actor" is gender neutral.
# 	  Unnamed characters played by a notable actor  / actress
# 	  Unnamed characters played by a notable actor
#
# ================================================================================
# EDIT: 393577373  COMMENT: rv extreme pov pushing
# 	 Male  genital mutilation , or as it is more commonly refereed to , male  circumcision  ,  involves the removal of the  foreskin .
# 	 Male circumcision involves the removal of the  foreskin .
#
# ================================================================================
# EDIT: 360678447  COMMENT: making neutral
# 	 Unfortunately  Nickelodeon did not pick the series up and it was pitched to the  BBC  who came  onboard  .
# 	 Nickelodeon did not pick the series up and it was pitched to the  BBC  who came  on board  .
#
# ================================================================================
# EDIT: 367745393  COMMENT: altered dreadful POV sentence to a more neutral form
# 	 Long   considered  one of the great beauties of this era , she is also a pioneer in the field of ethnic  cosmetics  and noted for her charitable work .
# 	 Considered   by some to be  one of the great beauties of this era , she is also a pioneer in the field of ethnic  cosmetics  and noted for her charitable work .
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 400715614  COMMENT: /* History */ npov
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 348619574  COMMENT: awkwardly worded and unnecessary. "reserves its finery" doesn't sound [[wp:npov|NPOV]]
# ================================================================================
# EDIT: 380486162  COMMENT: /* Career */ reword to stick to facts with a more neutral POV.
# ================================================================================
# EDIT: 360148684  COMMENT: /* Outcome */ npov
# 	 In , Paul ' s letters are referred to as " scripture ", which indicates the respect  Peter  had for Paul ' s apostolic authority ."
# 	 In , Paul ' s letters are referred to as " scripture ", which indicates the respect   the writer   had for Paul ' s apostolic authority ."
#
# ================================================================================
# EDIT: 390992121  COMMENT: current deemed sarcastic and therefore pov. also everything is considered "current" unless otherwise stated
# 	 The  current  position of the Vatican is that misunderstandings were created by a faulty Italian translation of Kowalska ' s Diary in that the questionable material could not be correlated with the original Polish version because of difficulties in communication throughout World War II and the subsequent  Communist   era .
# 	 The position of the Vatican is that misunderstandings were created by a faulty Italian translation of Kowalska ' s Diary in that the questionable material could not be correlated with the original Polish version because of difficulties in communication throughout World War II and the subsequent  Communist   era .
#
# ================================================================================
# EDIT: 388799694  COMMENT: /* Collections */ pov
# 	 Odd Nerdrum ' s work is held in several  important  public collections including the Hirshhorn Museum and Sculpture Garden in Washington , D .
# 	 Odd Nerdrum ' s work is held in several public collections including the Hirshhorn Museum and Sculpture Garden in Washington , D .
#
# MULTIPLE EDITS
# ================================================================================
# EDIT: 384058632  COMMENT: /* Life */  reword slightly to remove non-neutral adjective
# 	 After his  harrowing  escape and recapture upon turning back to save the life of his pursuer , he was  burned at the stake  near his hometown on 16 May 1569 .
# 	 After his escape and recapture upon turning back to save the life of his pursuer , he was  burned at the stake  near his hometown on 16 May 1569 .
#
# MULTIPLE EDITS
# ================================================================================
# EDIT: 356988877  COMMENT: /* Elected assemblies */ removed "successfully".  "successfully" implies the proposed change was a good thing; this is a matter of opinion; wiki should be neutral.
# 	 The first was held in  London in 1998  and was  successfully  passed .
# 	 The first was held in  London in 1998  and was passed .
#
# ================================================================================
# EDIT: 335491733  COMMENT: rm pov" exclusive"
# 	  The Boltons  is  an exclusive  street located in the  Kensington  area of southwest central  London ,  England  ( postcode  SW10 ).
# 	  The Boltons  is  a  street located in the  Kensington  area of southwest central  London ,  England  ( postcode  SW10 ).
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 372810003  COMMENT: more neutral wording
# 	 She was  de facto   monarch of England  after the death of  Edward VI  for just over a week in July 1553 .
# 	 She was  monarch of England ( at least   de facto   )  after the death of  Edward VI  for just over a week in July 1553 .
#
# ================================================================================
# EDIT: 370397359  COMMENT: /* Effectiveness */ Some criticisms are notable, well sourced and have got nothing to do with world bank's effectiveness or lack of. There is no pov issue with a section on criticism
# 	   Effectiveness
# 	   Criticism
#
# ================================================================================
# EDIT: 385620909  COMMENT: /* Design philosophy */ - `User friendliness' is relative. Changing to more neutral phrasing.
# 	 This   comes   at   the   cost  of  user - friendliness  .
# 	 As   a   result ,   users   with less knowledge  of  command line interfaces may experience a steeper learning curve , when using Slackware  .
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 390225583  COMMENT: /* Related studies */ more neutral language
# 	 Denny Borsboom ( 2006 )  finds  that mainstream contemporary test analysis does not reflect substantial recent developments in the field and " bears an uncanny resemblance to the psychometric state of the art as it existed in the 1950s ."
# 	 Denny Borsboom ( 2006 )  argues  that mainstream contemporary test analysis does not reflect substantial recent developments in the field and " bears an uncanny resemblance to the psychometric state of the art as it existed in the 1950s ."
#
# 	 For example , it  notes  that  IQ and the Wealth of Nations , in order to show that the tests are unbiased , uses outdated methodology , if anything indicative that test bias exist .. DENNY BORSBOOM .
# 	 For example , it  is argued  that  IQ and the Wealth of Nations , in order to show that the tests are unbiased , uses outdated methodology , if anything indicative that test bias exist .. DENNY BORSBOOM .
#
# ================================================================================
# EDIT: 359200994  COMMENT: /* Premise */ Reworded section to make more neutral and encyclopedic.
# ================================================================================
# EDIT: 357884769  COMMENT: gender-neutral language
# 	  The Hockey Stick Illusion  ( subtitle  Climategate and the Corruption of Science ) is a book written by  Andrew Montford , who is  skeptical that climate change is  man - made  .
# 	  The Hockey Stick Illusion  ( subtitle  Climategate and the Corruption of Science ) is a book written by  Andrew Montford , who is  skeptical that climate change is  caused by humans  .
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# LACKING TEXT
# LACKING TEXT
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 373949521  COMMENT: rm pov/or statement
# 	 She appears on the periphery of activities during that tempestuous time  , but then again , the deeds of few women of that time period were recorded  .
# 	 She appears on the periphery of activities during that tempestuous time .
#
# ================================================================================
# EDIT: 382188014  COMMENT: /* BDS and Delegitimization */ more neutral
# 	 Several analysts , journalists , and policy groups in Israel have  recently  argued that the BDS movement promotes the delegitimization of Israel .
# 	 Several analysts , journalists , and policy groups in Israel have argued that the BDS movement promotes the delegitimization of Israel .
#
# 	 In the Jersualem Post , Gil Troy argues that the BDS movement does not  really  target Israel ' s polices , but rather targets Israel ' s legitimacy .
# 	 In the Jersualem Post , Gil Troy argues that the BDS movement does not target Israel ' s polices , but rather targets Israel ' s legitimacy .
#
# 	 Similarly , The Reut Institute  has  argued that by  singling  out Israel and applying double standards , the BDS movement delegitimizes Israel .
# 	 Similarly , The    Reut Institute    argued that by  what   they perceive as singling  out Israel and applying double standards , the BDS movement delegitimizes Israel .
#
# 	 These groups and individuals argue that regardless of whether or not the participants in boycotts seek to threaten Israel ' s legitimacy , the movement itself and the organizers behind it have the same goal : isolate Israel like South Africa  and lead to its political implosion  .
# 	 These groups and individuals argue that regardless of whether or not the participants in boycotts seek to threaten Israel ' s legitimacy , the movement itself and the organizers behind it have the same goal : isolate Israel like South Africa .
#
# ================================================================================
# EDIT: 367714550  COMMENT: /* Early stages */ "was pushed" would need a good cite - moved is neutral
# 	 When  Brian Jones  joined the band on guitar , Taylor  was pushed  from guitar to bass and the band changed its name to  the Rollin ' Stones .
# 	 When  Brian Jones  joined the band on guitar , Taylor  moved  from guitar to bass and the band changed its name to  the Rollin ' Stones .
#
# LACKING TEXT
# MULTIPLE EDITS
# ================================================================================
# EDIT: 377614551  COMMENT: /* Controversy */ rm pov
# 	 The group  Council on American - Islamic Relations  ( CAIR )  ( which is a pro - Islamic lobby group that not only refuses to disclose the source of its funding ( which are reported to include Middle - Eastern governments including Iran ) but which also funds Hamas , a military organisation labelled " terrorist " by the US Government )  filed a Federal Elections Commission complaint against Clarion Fund , Inc .
# 	 The group  Council on American - Islamic Relations  ( CAIR ) filed a Federal Elections Commission complaint against Clarion Fund , Inc .
#
# ================================================================================
# EDIT: 403606919  COMMENT: This has not been agreed upon actually. We each wanted to state our personal interpretation outright, with myself losing interest quicker. This however, actually is neutral/says nothing. It simply doesn't tell the reader how to read the linked page.
# 	  thumb | right |  The  Sentience of the  Universe  merges with Galan of Taa  in the  Cosmic egg
# 	  thumb | right |  Galan of Taa and the  Sentience of the  Universe in the  Cosmic egg
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 389570417  COMMENT: unverified, not neutral
# MULTIPLE EDITS
# ================================================================================
# EDIT: 353071728  COMMENT: too much editorial commentary in these words, let's keep it neutral
# 	  Gavrilo Princip  ( Serbian Cyrillic : , ;  ) was a  Bosnian Serb   patriot  , associated with the  freedom  movement  Mlada Bosna  ( Young Bosnia ).
# 	  Gavrilo Princip  ( Serbian Cyrillic : , ;  ) was a  Bosnian Serb , associated with the movement  Mlada Bosna  ( Young Bosnia ).
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 340099680  COMMENT: /* Constitutional status */  indian (kashmiri parties )such as huriyet party want indepence and want autonomy/ but it is not listed in indian kashmir it is pov to list it here not also ind kashmir
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 395505976  COMMENT: /* Beginnings */ summ/npov
# 	 Alomar was born in  Palma de Mallorca  and raised in the  Balearic Islands , a  traditionally  conservative    province  of Spain  in which  the   hierarchical   power of the  Catholic Church  was very strong .
# 	 Alomar was born in  Palma de Mallorca  and raised in the  Balearic Islands , a  traditional   province  of Spain  where  the power of the  Catholic Church  was very strong .
#
# ================================================================================
# EDIT: 376583169  COMMENT: /* The effect */ More neutral.
# 	 Another side effect of the student movement was the  so - called   emancipation of women  in Germany .
# 	 Another side effect of the student movement was the  emancipation of women  in Germany .
#
# 	 Through their political work  the  women came to  be indoctrinated into  the  belief  that they were being suppressed by male society and that they thus had to change this condition .
# 	 Through their political work women came to the  opinion  that they were being suppressed by male society and that they thus had to change this condition .
#
# MULTIPLE EDITS
# ================================================================================
# EDIT: 403418034  COMMENT: /* Personal life */ npov
# 	 Coyote does not believe in the gender binary  but uses female pronouns  to set an example to others that female bodied people can look like anything that person wishes their body to look like  .
# 	 Coyote does not believe in the gender binary  but uses female pronouns .
#
# ================================================================================
# EDIT: 388385979  COMMENT: Changed "Due to" to "while" in suicide reference for neutral point of view
# 	 Due to  suffering a bout of health problems , he committed suicide on February 20 , 2005 , at the age of 67 .
# 	 While  suffering a bout of health problems , he committed suicide on February 20 , 2005 , at the age of 67 .
#
# ================================================================================
# EDIT: 396348518  COMMENT: /* Supreme Court tenure */ Modifying this to make it more neutral
# 	 Snepp later pointed out that Powell had misstated the factual record and had not reviewed the actual case file ( Powell was  notorious   for his sloppy  habit of writing opinions based on the briefs alone ) and that the only justice who even looked at the case file was  John Paul Stevens , who relied upon it in composing his dissent .
# 	 Snepp later pointed out that Powell had misstated the factual record and had not reviewed the actual case file ( Powell was  in   the  habit of writing opinions based on the briefs alone ) and that the only justice who even looked at the case file was  John Paul Stevens , who relied upon it in composing his dissent .
#
# ================================================================================
# EDIT: 341781929  COMMENT: /* Criticism and controversies */ entire section needs to be balanced and written from neutral sources
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 397682613  COMMENT: /* Critical response */ pov; not part of ref
# ================================================================================
# EDIT: 367755031  COMMENT: changed the politically charged "Death Tax" to the more neutral "Estate tax"
# 	 He voted Yes on a Balanced - budget constitutional amendment , has expressed support for a low tax and spend approach , opposes the   Death   Tax  , and was rated 100 percent by the  Cato Institute , indicating a pro - free trade  voting record .
# 	 He voted Yes on a Balanced - budget constitutional amendment , has expressed support for a low tax and spend approach , opposes the   Estate   tax in the United States | Estate tax  , and was rated 100 percent by the  Cato Institute , indicating a pro - free trade  voting record .
#
# ================================================================================
# EDIT: 356047681  COMMENT: gender neutral
# 	  Salt evaporation ponds  are shallow  man - made   pond  s designed to produce  salt  s from  sea water  or other  brine  s .
# 	  Salt evaporation ponds  are shallow  artificial   pond  s designed to produce  salt  s from  sea water  or other  brine  s .
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# LACKING TEXT
# LACKING TEXT
# ================================================================================
# EDIT: 348050093  COMMENT: /* Structure */ Please stop adding unscholarly references for a pov that isn't supported in biblical scholarship
# ================================================================================
# EDIT: 389604526  COMMENT: pov award intro
# 	  Good Eats  is a   Peabody Award - winning   television   cooking show  created and hosted by  Alton Brown  that airs in  North America  on  Food Network .
# 	  Good Eats  is a  television   cooking show  created and hosted by  Alton Brown  that airs in  North America  on  Food Network .
#
# MULTIPLE EDITS
# LACKING TEXT
# MULTIPLE EDITS
# ================================================================================
# EDIT: 347383524  COMMENT: version is correct, 'commandments' is pov
# 	  thumb | The stone featuring the English  commandments  .
# 	  thumb | The stone featuring the English  version  .
#
# MULTIPLE EDITS
# MULTIPLE EDITS
# MULTIPLE EDITS
# ================================================================================
# EDIT: 385617348  COMMENT: /* UFCW 8 GS */  rephrase to reflect neutral POV
# 	 On September 30 , 2009 , UFCW 8 Golden State members , stewards , and volunteers established informational picket lines at four Fresh and Easy stores in Kern County  protesting  Fresh & Easy ' s threat to Union market share , and U .
# 	 On September 30 , 2009 , UFCW 8 Golden State members , stewards , and volunteers established informational picket lines at four Fresh and Easy stores in Kern County  to protest what they consider to be  Fresh & Easy ' s threat to Union market share , and U .
#
# ================================================================================
# EDIT: 338295006  COMMENT: /* The incident */ "to strike Gammage again" is not neutral.  Since police hold flashlights at head level, Vojtas's intention cannot be known.
# 	 When he raised his flashlight  to strike Gammage again  , Gammage knocked the flashlight from Vojtas ' s hand .
# 	 When he raised his flashlight , Gammage knocked the flashlight from Vojtas ' s hand .
#
# ================================================================================
# EDIT: 391052099  COMMENT: Anwar give us some space !!! research on other article in comparison to this. You are not allowing to edit endhiran saying its succes, which created records in indian history !! It is neutral here.
# 	 Endhiran grossed  62 crore from all versions in the first weekend  and  117 Crore in the first week  reached a new milestone for  a   Tamil  film .
# 	 Endhiran grossed  62 crore from all versions in the first weekend  and  117 Crore in the first week  reached a new milestone for  any   Indian  film .

# %%
sample_revision('341673195')
# Out:
# ================================================================================
# EDIT: 341673195  COMMENT: Made more neutral
# 13
# 	  Alphascript  publishing   is a trademark of VDM Publishing House and is used to sell Wikipedia articles as  expensive  books  . Its mercantil philosophy is clearly exposed on Alphascript ' s site  : " with the Wikipedia - texts at free disposal we create books on interesting topics ."
# 	  Alphascript  Publishing   is a trademark of VDM Publishing House and is used to sell Wikipedia articles as  commercial print  books : " with the Wikipedia - texts at free disposal we create books on interesting topics ."
